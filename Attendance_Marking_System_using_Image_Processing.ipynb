# %% [markdown]
# <a href="https://colab.research.google.com/github/marioshady/Attendance-Marking-System/blob/main/Attendance_Marking_System_using_Image_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import face_recognition
from google.colab.patches import cv2_imshow 
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import matplotlib.pyplot as plt

# %%
imgElon = face_recognition.load_image_file('/content/gdrive/MyDrive/images/elonmusk.jpg')
imgElon = cv2.cvtColor(imgElon,cv2.COLOR_BGR2RGB)
#3ashan te3'aiar el soora elly hat-test beeha change hena
imgTest = face_recognition.load_image_file('/content/gdrive/MyDrive/images/elonmusk2.jpg')
imgTest = cv2.cvtColor(imgTest,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imgElon)
plt.show()

# %%
#di elsoora elly han-test beeha "billgates or elonmusk2"
plt.imshow(imgTest)
plt.show()

# %%
image = cv2.imread('/content/gdrive/MyDrive/images/elonmusk.jpg')
image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
se=cv2.getStructuringElement(cv2.MORPH_RECT , (8,8))
bg=cv2.morphologyEx(image, cv2.MORPH_DILATE, se)
out_gray=cv2.divide(image, bg, scale=255)
out_binary=cv2.threshold(out_gray, 0, 255, cv2.THRESH_OTSU )[1] 

cv2_imshow(out_binary)  
cv2.imwrite('binary.png',out_binary)
# Out:
# <PIL.Image.Image image mode=L size=1200x1200 at 0x7F1EB02C2ED0>
# True

# %%
cv2_imshow( out_gray)  
cv2.imwrite('gray.png',out_gray)
# Out:
# <PIL.Image.Image image mode=L size=1200x1200 at 0x7F1EB02AE890>
# True

# %%
#3ashan te3'aiar el soora elly hat-test beeha change hena kamaan 
image2 = cv2.imread('/content/gdrive/MyDrive/images/elonmusk2.jpg')
image2=cv2.cvtColor(image2,cv2.COLOR_BGR2GRAY)
se2=cv2.getStructuringElement(cv2.MORPH_RECT , (8,8))
bg2=cv2.morphologyEx(image2, cv2.MORPH_DILATE, se)
out_gray2=cv2.divide(image2, bg2, scale=255)
out_binary2=cv2.threshold(out_gray2, 0, 255, cv2.THRESH_OTSU )[1] 

cv2_imshow(out_binary2)  
cv2.imwrite('binary.png',out_binary2)
# Out:
# <PIL.Image.Image image mode=L size=780x438 at 0x7F1EB02C25D0>
# True

# %%
cv2_imshow( out_gray2)  
cv2.imwrite('gray.png',out_gray2)
# Out:
# <PIL.Image.Image image mode=L size=780x438 at 0x7F1EB024FE50>
# True

# %%
faceLoc = face_recognition.face_locations(imgElon)[0]
encodeElon = face_recognition.face_encodings(imgElon)[0]
cv2.rectangle(imgElon,(faceLoc[3],faceLoc[0]),(faceLoc[1],faceLoc[2]),(255,0,255),2)
# Out:
# array([[[234, 240, 245],
#         [234, 240, 245],
#         [234, 240, 247],
#         ...,
#         [170,  84,  66],
#         [170,  84,  66],
#         [170,  84,  66]],
#
#        [[234, 240, 245],
#         [234, 240, 245],
#         [234, 240, 247],
#         ...,
#         [170,  84,  66],
#         [170,  84,  66],
#         [170,  84,  66]],
#
#        [[234, 240, 247],
#         [234, 240, 247],
#         [234, 240, 247],
#         ...,
#         [170,  84,  66],
#         [170,  84,  66],
#         [170,  84,  66]],
#
#        ...,
#
#        [[135,  67,  48],
#         [136,  68,  49],
#         [136,  68,  49],
#         ...,
#         [  1,   1,   1],
#         [  1,   1,   1],
#         [  1,   1,   1]],
#
#        [[135,  67,  48],
#         [135,  67,  48],
#         [136,  68,  49],
#         ...,
#         [  1,   1,   1],
#         [  1,   1,   1],
#         [  1,   1,   1]],
#
#        [[135,  67,  48],
#         [135,  67,  48],
#         [135,  67,  48],
# ...

# %%
faceLocTest = face_recognition.face_locations(imgTest)[0]
encodeTest = face_recognition.face_encodings(imgTest)[0]
cv2.rectangle(imgTest,(faceLocTest[3],faceLocTest[0]),(faceLocTest[1],faceLocTest[2]),(255,0,255),2)
# Out:
# array([[[ 16,  19,  24],
#         [ 14,  17,  22],
#         [ 11,  14,  19],
#         ...,
#         [ 19,  18,  20],
#         [ 14,  16,  17],
#         [  0,   3,   4]],
#
#        [[ 12,  15,  20],
#         [ 10,  13,  18],
#         [  7,  10,  15],
#         ...,
#         [ 17,  16,  18],
#         [ 28,  30,  31],
#         [  6,  10,  11]],
#
#        [[  8,  11,  16],
#         [  7,  10,  15],
#         [  5,   8,  13],
#         ...,
#         [  2,   1,   3],
#         [  5,   7,   8],
#         [  1,   5,   6]],
#
#        ...,
#
#        [[ 75,  84,  93],
#         [ 73,  82,  91],
#         [ 76,  87,  95],
#         ...,
#         [103, 100,  96],
#         [ 89,  86,  82],
#         [ 81,  79,  78]],
#
#        [[101, 113, 125],
#         [ 96, 108, 120],
#         [ 94, 106, 118],
#         ...,
#         [106, 103,  99],
#         [ 91,  88,  84],
#         [ 83,  81,  80]],
#
#        [[111, 127, 140],
#         [104, 120, 133],
#         [ 98, 114, 127],
# ...

# %%
#hena garabna n-test sooret elon musk w sooret bill gates ... then hena ba2a hangarab elon musk w elon musk w neshof true wala false sheel ay billgates ma7toota w 7ot elonmusk2
results = face_recognition.compare_faces([encodeElon],encodeTest) 
faceDis = face_recognition.face_distance([encodeElon],encodeTest)
cv2.putText(imgTest,f'{results} {round(faceDis[0],2)}',(50,50),cv2.FONT_HERSHEY_COMPLEX,1,(0,0,255),2)
print(results, faceDis)
# Out:
# [True] [0.38672208]

# %%
img = cv2.imread('/content/gdrive/MyDrive/images/elonmusk.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1200 at 0x7F1EB0380F90>
# -1

# %%
img2 = cv2.imread('/content/gdrive/MyDrive/images/elonmusk2.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=780x438 at 0x7F1EB049D650>
